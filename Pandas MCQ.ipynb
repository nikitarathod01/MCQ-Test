# %% [raw]
# 1.	: What does Pandas stand for?
# a) Panel Data System
# b) Python Data System
# c) Python Data Analysis
# d) Python for Data Structures
# ANS: c. Python Data Analysis
#
# 2.	: What is the primary data structure in Pandas for holding data?
# a) DataFrame
# b) Series
# c) Dictionary
# d) Array
#
# ANS: a. DataFrame
#
# 3.	: How can you read a CSV file into a Pandas DataFrame?
# a) pd.read_csv("file.csv")
# b) pd.read("file.csv")
# c) pd.load_csv("file.csv")
# d) pd.from_csv("file.csv")
#
# ANS: a. pd.read_csv(“file.csv”)
#
# 4.	: What does the head() function in Pandas do?
# a) Returns the first few rows of a DataFrame.
# b) Returns the last few rows of a DataFrame.
# c) Returns summary statistics of a DataFrame.
# d) None of the above.
# ANS: a. Returns the first few rows of a DataFrame.
# 5.	: How can you select a specific column 'column_name' from a DataFrame df? a) df.select('column_name')
# b) df['column_name']
# c) df.column_name
# d) df.loc['column_name']
# ANS: b. df[‘column_name’]
#
# 6.	: What does the groupby() function in Pandas do?
# a) Groups the data based on a specific column.
# b) Calculates the mean value of each group.
# c) Applies a function to each group separately.
# d) All of the above.
#
# ANS: a. Groups the data based on a specific column.
# .
# 7.	: How can you remove rows with missing values from a DataFrame df?
# a) df.remove_null()
# b) df.dropna()
# c) df.drop_null()
# d) df.remove_na()
#
# ANS: b. df.dropna()
#
#
# 8.	: What does the merge() function in Pandas do?
# a) Combines multiple DataFrames vertically.
# b) Combines multiple DataFrames horizontally.
# c) Merges DataFrames based on a common column.
# d) None of the above.
#
# ANS: c. Merges DataFrames based on a common column.
#
#
# 9.	: How can you rename the column 'old_name' to 'new_name' in a DataFrame df?
# a) df.rename_column('old_name', 'new_name')
# b) df.rename(columns={'old_name': 'new_name'}) c)df.column_rename('old_name', 'new_name') d)df.rename_column({'old_name': 'new_name'})
#
# ANS: b. df.rename(columns={'old_name': 'new_name'})
#
# 10.	: What is the purpose of the pivot_table() function in Pandas?
# a) Creates a pivot table with aggregated data.
# b) Pivots a DataFrame from long to wide format.
# c) Rearranges data to make it more readable.
# d) None of the above.
#
# ANS: a. Creates a pivot table with aggregated data.
#
#
# 11.	: How can you sort a DataFrame df based on values in the column 'column_name' in ascending order?
# a) df.sort('column_name')
# b) df.sort_values('column_name', ascending=True)
# c) df.sort_by('column_name')
# d) df.order_by('column_name')
# ANS: b.  df.sort_values('column_name', ascending=True)
#
#
# 12.	: What does the map() function do in Pandas?
# a) Applies a function element-wise to a Series.
# b) Replaces values in a Series based on a mapping dictionary.
# c) Converts a Series to a DataFrame.
# d) None of the above.
#
# ANS: a. Applies a function element-wise to a Series
#
# 13.	: How can you convert a DataFrame df to a CSV file named 'output.csv'?
# a) df.write_csv('output.csv')
# b) df.save_csv('output.csv')
# c) df.to_csv('output.csv')
# d) df.export_csv('output.csv')
#
# ANS: c. df.to_csv('output.csv')
#
# 14.	: What does the iloc[] attribute in Pandas do?
# a) Retrieves data based on row and column labels.
# b) Retrieves data based on row and column indices.
# c) Sets data based on row and column labels.
# d) Sets data based on row and column indices.
#
# ANS: b. Retrieves data based on row and column indices.
#
# 15.	: How can you calculate the correlation matrix for a DataFrame df?
# a) df.correlation_matrix()
# b) df.correlate()
# c) df.corr()
# d) df.calculate_correlation()
#
# ANS: c. df.corr()
#
#
#
# 16.	: What does the apply() function in Pandas do?
# a) Applies a function element-wise to a DataFrame.
# b) Applies a function to each group separately.
# c) Applies a function to each row or column.
# d) All of the above.
#
# ANS: d. All of the above.
#
#
# 17.	: How can you create a new column 'new_column' in a DataFrame df that contains the sum of two existing columns 'col1' and 'col2'?
# a) df['new_column'] = df['col1'] + df['col2']
# b) df.add_column('new_column', df['col1'] + df['col2'])
# c) df.new_column = df.col1 + df.col2
# d) df.set_column('new_column', df.col1 + df.col2)
#
# ANS: a) df['new_column'] = df['col1'] + df['col2']
#
# 18.	: What does the describe() function in Pandas do?
# a) Returns summary statistics of a DataFrame.
# b) Describes the structure of a DataFrame.
# c) Summarizes data based on a specific column.
# d) None of the above.
#
# ANS: a. Returns summary statistics of a DataFrame.
#
# 19.	: How can you calculate the cumulative sum of a DataFrame df along the columns?
# a) df.cumulative_sum(axis=0)
# b) df.cumsum(axis=1)
# c) df.cumulative(axis=1)
# d) df.cumulative_sum(axis=1)
#
# ANS: d. df.cumulative_sum(axis=1)
#
#
# 20.	: What does the duplicated() function in Pandas do?
# a) Identifies duplicate rows in a DataFrame.
# b) Identifies duplicate columns in a DataFrame.
# c) Removes duplicate rows from a DataFrame.
# d) None of the above.
#
# ANS: a. Identifies duplicate rows in a DataFrame.
#
#
# 21.	: How can you extract the unique values from a specific column 'column_name' in a DataFrame df?
# a) df.unique('column_name')
# b) df['column_name'].unique()
# c) df.get_unique('column_name')
# d) df.column_name.unique()
#
# ANS: b. df[‘column_name’].unique()
# To extract unique values from a specific column 'column_name' in a DataFrame df, you can use the df['column_name'].unique() method.
#
# 22.	: What does the resample() function in Pandas do?
# a) Aggregates data over a specific time period.
# b) Fills missing values in a DataFrame.
# c) Reindexes a DataFrame with a new time frequency.
# d) None of the above.
#
# ANS: a. Aggregates data over a specific time period.
# The resample() function in Pandas aggregates data over a specific time period, commonly used in time series data.
#
# 23.	: How can you create a new column 'new_column' in a DataFrame df that contains the row-wise mean of all columns?
# a) df.new_column = df.mean(axis=1)
# b) df['new_column'] = df.mean(axis=1)
# c) df.insert('new_column', df.mean(axis=1))
# d) df['new_column'] = df.sum(axis=1) / len(df.columns)
#
# ANS: b. df[‘new column’] = df.mean(axis=1)
# To create a new column 'new_column' in a DataFrame df that contains the row-wise mean of all columns, you can use df['new_column'] = df.mean(axis=1).
#
# 24.	: What does the transform() function in Pandas do?
# a) Applies a function element-wise to a DataFrame.
# b) Applies a function to each group separately.
# c) Applies a function to each row or column.
# d) Replaces values in a Series based on a mapping dictionary.
#
# ANS: a. Applies a function element-wise to a DataFrame.
# The transform() function in Pandas applies a function element-wise to a DataFrame.
#
#
# 25.	: How can you calculate the z-scores of a specific column 'column_name' in a DataFrame df?
# a) df['column_name'].zscore()
# b) (df['column_name'] - df['column_name'].mean()) / df['column_name'].std()
# c) df['column_name'].transform(lambda x: (x - x.mean()) / x.std())
# d) All of the above
#
# ANS: b. (df[‘column_name] – df[‘column_name’].mean()) / df[‘column_name’].std()
# To calculate the z-scores of a specific column 'column_name' in a DataFrame df, you can use the formula (df['column_name'] - df['column_name'].mean()) / df['column_name'].std().
#
#
# 26.	: What does the drop_duplicates() function in Pandas do?
# a) Drops rows with missing values from a DataFrame.
# b) Drops duplicate rows from a DataFrame.
# c) Drops columns with missing values from a DataFrame.
#            d) Drops columns with duplicate values from a DataFrame.
#
# ANS: b. Drops duplicate rows from a DataFrame.
# The drop_duplicates() function in Pandas drops duplicate rows from a DataFrame.
#
# 27.	: How can you calculate the element-wise product of two DataFrames df1 and df2?
# a) df1 * df2
# b) df1.mul(df2)
# c) df1.product(df2)
# d) df1.elementwise(df2)
#
# ANS: b. df.mul(df2)
# To calculate the element-wise product of two DataFrames df1 and df2, you can use the df1.mul(df2) method.
#
#
# 28.	: What does the ffill() function in Pandas do?
# a) Fills missing values forward (from top to bottom) in a DataFrame.
# b) Fills missing values backward (from bottom to top) in a DataFrame.
# c) Fills missing values based on a specified method.
# d) Fills all values in a DataFrame with a specific value.
#
# ANS: a. Fills missing values forward (from top to bottom) in DataFrame.
# The ffill() function in Pandas fills missing values forward (from top to bottom) in a DataFrame.
#
# 29.	: How can you create a pivot table with multiple aggregation functions for a DataFrame df?
# a) df.pivot_table(values='value_column', index='index_column', columns='columns_column', aggfunc=['sum', 'mean'])
# b) df.pivot_table(values='value_column', index='index_column', columns='columns_column', aggfunc='sum', aggfunc='mean')
# c) df.pivot_table(values='value_column', index='index_column', columns='columns_column', aggfunc='sum, mean')
# d) df.pivot_table(values='value_column', index='index_column', columns='columns_column', aggfunc='sum_mean')
#
# ANS: a. df.pivot_table(values = ‘value_column’, index=’index_column’,
# To create a pivot table with multiple aggregation functions for a DataFrame df, you can use the df.pivot_table() method with the aggfunc parameter specifying multiple functions.
#
# 30.	: What does the cut() function in Pandas do?
# a) Categorizes continuous data into intervals or bins.
# b) Cuts a DataFrame into smaller pieces.
# c) Cuts a Series into smaller segments.
# d) Converts a DataFrame to a categorical data type.
#
# ANS: a. Categorizes continuous data into intervals or bins.
# The cut() function in Pandas categorizes continuous data into intervals or bins.
#
#
# 31.	: How can you handle missing values in a DataFrame df by filling them with the mean value of the column?
# a) df.fillna(df.mean())
# b) df.fillna(df.mean(), axis=0)
# c) df.fillna(df.mean(), axis=1)
# d) df.fillna(df.mean(), inplace=True)
#
# ANS: b. df.fillna(df.mean(), axis=0)
# To handle missing values in a DataFrame df by filling them with the mean value of the column, you can use df.fillna(df.mean(), axis=0).
#
#
# 32.	: What does the applymap() function in Pandas do?
# a) Applies a function element-wise to a DataFrame.
# b) Applies a function to each row or column.
# c) Applies a function to each group separately.
# d) Applies a function to each element in a DataFrame.
#
# ANS: d. Applies a function to each element in a DataFrame.
# The applymap() function in Pandas applies a function to each element in a DataFrame.
#
# 33.	MCQ: How can you replace all occurrences of a specific value (e.g., 'old_value') in a DataFrame df with a new value (e.g., 'new_value')?
# a) df.replace('old_value', 'new_value')
# b) df.replace('old_value', 'new_value', inplace=True)
# c) df.replace_values({'old_value': 'new_value'})
# d) df.replace_values('old_value', 'new_value')
#
# ANS: a. df.replace(‘old_value’, ‘new_value’)
# To replace all occurrences of a specific value ('old_value') in a DataFrame df with a new value ('new_value'), you can use df.replace('old_value', 'new_value').
#
#
# 34.	: What does the merge_asof() function in Pandas do?
# a) Merges two DataFrames based on the closest match to a key column.
# b) Merges two DataFrames based on a common column.
# c) Merges two DataFrames based on a specified time interval.
# d) None of the above.
#
# ANS: a. Merges two DataFrame based on the closest match to key column.
# The merge_asof() function in Pandas merges two DataFrames based on the closest match to a key column.
#
# 35.	: How can you calculate the percentage change of a DataFrame df along the columns?
# a) df.pct_change()
# b) df.calculate_change()
# c) df.percent_change()
# d) df.change()
#
# ANS: a. df.pct_change()
# To calculate the percentage change of a DataFrame df along the columns, you can use df.pct_change().
#
#
# 36.	: What does the dt accessor in Pandas do?
# a) Provides access to datetime properties and methods in a Series.
# b) Converts a Series to a datetime data type.
# c) Converts a Series to a timedelta data type.
# d) None of the above.
#
# ANS: a. Provides access to determine properties and methods in a series.
# The dt accessor in Pandas provides access to datetime properties and methods in a Series.
#
# 37.	: How can you perform element-wise subtraction of two DataFrames df1 and df2 and replace missing values with 0?
# a) df1 - df2
# b) df1.subtract(df2, fill_value=0)
# c) df1.sub(df2, fill_value=0)
# d) df1.elementwise(df2, fill_value=0)
#
# ANS: b. df1.substract(df2, fill_value=0)
# To perform element-wise subtraction of two DataFrames df1 and df2 and replace missing values with 0, you can use df1.subtract(df2, fill_value=0).
#
# 38.	: What does the to_datetime() function in Pandas do?
# a) Converts a Series to a datetime data type.
# b) Converts a Series to a timedelta data type.
# c) Converts a Series to a string representation of the datetime.
# d) Converts a datetime to a string representation.
#
# ANS: a. Converts a series to a datetime data type.
# The to_datetime() function in Pandas converts a Series to a datetime data type.
#
# 39.	: How can you select rows from a DataFrame df where the values in column 'column_name' are not null?
# a) df[df.column_name.notnull()]
# b) df[df.column_name != null]
# c) df[df.column_name.notna()]
# d) All of the above
#
# ANS: a. df[df.column_name.notnull()]
# To select rows from a DataFrame df where the values in column 'column_name' are not null, you can use df[df.column_name.notnull()].
#
#
# 40.	: What does the query() function in Pandas do?
# a) Selects rows from a DataFrame based on a query string.
# b) Performs SQL-like operations on a DataFrame.
# c) Calculates the mean value of each group.
# d) None of the above.
#
# ANS: a. Selects rows from a DataFrame based on a query string.
# The query() function in Pandas selects rows from a DataFrame based on a query string.
